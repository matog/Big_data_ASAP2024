# %% [markdown]
# # Webscrapping de datos de MercadoLibre

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

# %% [markdown]
# ## Scrappeamos una sóla página

# %%
# Definimos la URL para scrappear
# url = 'https://www.mercadolibre.com.ar/mas-vendidos#menu=categories' 
url = 'https://listado.mercadolibre.com.ar/notebook#trends_tracking_id=61b3c37c-e0da-4304-ac5f-cb66f17b876e&component_id=MOST_WANTED'

# Hacemos el request de la url, y luego lo metemos en BeautifulSoup
html = requests.get(url.strip(), headers={'User-Agent': 'Mozilla/5.0'}).text

# %%
html
# Out:
# '\n<!DOCTYPE html>\n<html lang="es-AR">\n<head><link rel="preconnect" href="https://www.google-analytics.com"/><link rel="preconnect" href="https://www.google.com"/><link rel="preconnect" href="https://data.mercadolibre.com"/><link rel="preconnect" href="https://http2.mlstatic.com"/><link rel="preconnect" href="https://stats.g.doubleclick.net"/><link rel="preconnect" href="https://analytics.mercadolibre.com.ar"/><link rel="preconnect" href="https://analytics.mercadolibre.com"/><link rel="preconnect" href="https://www.google.com.ar"/><script type=\'text/javascript\'>window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"NRBR-766f4fb616d3a2368ce","applicationID":"1729522169","agentToken":null,"applicationTime":1030.658199,"transactionName":"YlZQYEVZC0QEV0BZV1scd0xHSgBEFl5HH39wZx0bHQ==","queueTime":0,"ttGuid":"31acbebe6081ac9a"}; (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"1834861763",accountID:"989586",trustKey:"1709707",xpid:"XQ4OVF5VGwIHVlhXBQMGUF0=",licenseKey:"NRBR-766f4fb616d3a2368ce",applicationID:"1729522169"};;(()=>{"use strict";var e,t,r={9071:(e,t,r)=>{r.d(t,{I:()=>n});var n=0,i=navigator.userAgent.match(/Firefox[\\/\\s](\\d+\\.\\d+)/);i&&(n=+i[1])},8768:(e,t,r)=>{r.d(t,{T:()=>n,p:()=>i});const n=/(iPad|iPhone|iPod)/g.test(navigator.userAgent),i=n&&Boolean("undefined"==typeof SharedWorker)},880:(e,t,r)=>{r.d(t,{P_:()=>l,Mt:()=>g,C5:()=>s,DL:()=>v,OP:()=>T,lF:()=>D,Yu:()=>y,Dg:()=>h,CX:()=>c,GE:()=>b,sU:()=>_});var n=r(6797),i=r(4286);const o={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o),(0,n.Qy)(e,a[e],"info")}var u=r(2797);const d=()=>{const e={blockSelector:"[data-nr-block]",maskInputOptions:{password:!0}};return{allow_bfcache:!0,privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,enabled:!0,harvestTimeSeconds:10},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:u.oD,inactiveMs:u.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10},metrics:{enabled:!0},page_action:{enabled:!0,harvestTimeSeconds:30},page_view_event:{enabled:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1},session_trace:{enabled:!0,harvestTimeSeconds:10},session_replay:{enabled:!1,harvestTimeSeconds:60,sampleRate:.1,errorSampleRate:.1,maskTextSelector:"*",maskAllInputs:!0,get blockClass(){return"nr-block"},get ignoreClass(){return"nr-ignore"},get maskTextClass(){return"nr-mask"},get blockSelector(){return e.blockSelector},set blockSelector(t){e.blockSelector+=",".concat(t)},get maskInputOptions(){return e.maskInputOptions},set maskInputOptions(t){e.maskInputOptions={...t,password:!0}}},spa:{enabled:!0,harvestTimeSeconds:10}}},f={};function l(e){if(!e)throw new Error("All configuration objects require an agent identifier!");if(!f[e])throw new Error("Configuration for ".concat(e," was never set"));return f[e]}function h(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");f[e]=(0,i.D)(t,d()),(0,n.Qy)(e,f[e],"config")}function g(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");var r=l(e);if(r){for(var n=t.split("."),i=0;i<n.length-1;i++)if("object"!=typeof(r=r[n[i]]))return;r=r[n[n. ...

# %%
soup = BeautifulSoup(html, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="es-AR">
# <head><link href="https://www.google-analytics.com" rel="preconnect"/><link href="https://www.google.com" rel="preconnect"/><link href="https://data.mercadolibre.com" rel="preconnect"/><link href="https://http2.mlstatic.com" rel="preconnect"/><link href="https://stats.g.doubleclick.net" rel="preconnect"/><link href="https://analytics.mercadolibre.com.ar" rel="preconnect"/><link href="https://analytics.mercadolibre.com" rel="preconnect"/><link href="https://www.google.com.ar" rel="preconnect"/><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"NRBR-766f4fb616d3a2368ce","applicationID":"1729522169","agentToken":null,"applicationTime":1030.658199,"transactionName":"YlZQYEVZC0QEV0BZV1scd0xHSgBEFl5HH39wZx0bHQ==","queueTime":0,"ttGuid":"31acbebe6081ac9a"}; (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"1834861763",accountID:"989586",trustKey:"1709707",xpid:"XQ4OVF5VGwIHVlhXBQMGUF0=",licenseKey:"NRBR-766f4fb616d3a2368ce",applicationID:"1729522169"};;(()=>{"use strict";var e,t,r={9071:(e,t,r)=>{r.d(t,{I:()=>n});var n=0,i=navigator.userAgent.match(/Firefox[\/\s](\d+\.\d+)/);i&&(n=+i[1])},8768:(e,t,r)=>{r.d(t,{T:()=>n,p:()=>i});const n=/(iPad|iPhone|iPod)/g.test(navigator.userAgent),i=n&&Boolean("undefined"==typeof SharedWorker)},880:(e,t,r)=>{r.d(t,{P_:()=>l,Mt:()=>g,C5:()=>s,DL:()=>v,OP:()=>T,lF:()=>D,Yu:()=>y,Dg:()=>h,CX:()=>c,GE:()=>b,sU:()=>_});var n=r(6797),i=r(4286);const o={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o),(0,n.Qy)(e,a[e],"info")}var u=r(2797);const d=()=>{const e={blockSelector:"[data-nr-block]",maskInputOptions:{password:!0}};return{allow_bfcache:!0,privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,enabled:!0,harvestTimeSeconds:10},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:u.oD,inactiveMs:u.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10},metrics:{enabled:!0},page_action:{enabled:!0,harvestTimeSeconds:30},page_view_event:{enabled:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1},session_trace:{enabled:!0,harvestTimeSeconds:10},session_replay:{enabled:!1,harvestTimeSeconds:60,sampleRate:.1,errorSampleRate:.1,maskTextSelector:"*",maskAllInputs:!0,get blockClass(){return"nr-block"},get ignoreClass(){return"nr-ignore"},get maskTextClass(){return"nr-mask"},get blockSelector(){return e.blockSelector},set blockSelector(t){e.blockSelector+=",".concat(t)},get maskInputOptions(){return e.maskInputOptions},set maskInputOptions(t){e.maskInputOptions={...t,password:!0}}},spa:{enabled:!0,harvestTimeSeconds:10}}},f={};function l(e){if(!e)throw new Error("All configuration objects require an agent identifier!");if(!f[e])throw new Error("Configuration for ".concat(e," was never set"));return f[e]}function h(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");f[e]=(0,i.D)(t,d()),(0,n.Qy)(e,f[e],"config")}function g(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");var r=l(e);if(r){for(var n=t.split("."),i=0;i<n.length-1;i++)if("object"!=typeof(r=r[n[i]]))return;r=r[n[n.length-1]]}return r}const p={accountID:void 0,tr ...
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0" name="viewport"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="samesite=true" name="browser-support"/>
# <meta content="icnNa5wm-5FB5L3mf0yJYpMS2Lmg2rT58yzE" name="csrf-token"/>
# <link as="font" crossorigin="anonymous" data-head-react="true" href="https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-head-react="true" href="https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-head-react="true" href="https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.woff2" rel="preload" type="font/woff2"/><style data-head-react="true">@font-face{font-family:'Proxima Nova';font-weight:300;font-display:swap;font-style:normal;src:url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.woff2) format("woff2"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.woff) format("woff"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-light.ttf) format("truetype")}@font-face{font-family:'Proxima Nova';font-weight:400;font-display:swap;font-style:normal;src:url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.woff2) format("woff2"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.woff) format("woff"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-regular.ttf) format("truetype")}@font-face{font-family:'Proxima Nova';font-weight:600;font-display:swap;font-style:normal;src:url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.woff2) format("woff2"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.woff) format("woff"),url(https://http2.mlstatic.com/ui/webfonts/v3.0.0/proxima-nova/proximanova-semibold.ttf) format("truetype")}</style><link data-head-react="true" href="https://http2.mlstatic.com/frontend-assets/ml-web-navigation/ui-navigation/5.21.22/mercadolibre/favicon.svg" rel="icon"/><link data-head-react="true" href="https://http2.mlstatic.com/frontend-assets/ml-web-navigation/ui-navigation/5.21.22/mercadolibre/180x180.png" rel="apple-touch-icon"/><script type="application/ld+json">{"@context":"https:\u002F\u002Fschema.org","@graph":[{"@type":"SearchResultsPage","id":"https:\u002F\u002Flistado.mercadolibre.com.ar\u002Fnotebook","name":"Notebook","about":"Envíos Gratis en el día ✓ Comprá Notebook en cuotas sin interés! Conocé nuestras increíbles ofertas y promociones en millones de productos."},{"@type":"ItemList","id":"https:\u002F\u002Flistado.mercadolibre.com.ar\u002Fnotebook\u002F#itemList","numberOfItems":1,"itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Product","name":"Notebook Asus Vivobook 15 X1502 azul 15.6\", Intel Core i5 1240P 8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 80EUs Windows 11 Home","aggregateRating":{"@type":"AggregateRating","ratingCount":122,"bestRating":5,"ratingValue":4.6,"worstRating":1},"offers":{"@type":"AggregateOffer","price":368999,"lowPrice":368999,"priceCurrency":"ARS","offerCount":1,"availability":"https:\u002F\u002Fschema.org\u002FInStock","itemCondition":"https:\u002F\u002Fschema.org\u002FNewCondition"},"brand":{"@type":"Brand","name":"Asus"}}}]}]}</script><link as="image" data-head-react="true" fetchpriority="high" href="https://http2.mlstatic.com/D_NQ_NP_677215-MLA69719305778_052023-OO.jpg" rel="preload"/><title>Notebook | MercadoLibre 📦</title><meta content="Envíos Gratis en el día ✓ Comprá Notebook en cuotas sin interés! Conocé nuestras increíbles ofertas y promociones en millones de productos." data-head-react="true" name="description"/><link data-head-react="true" href="https://listado.mercadolibre.com.ar/notebook" rel="canonical"/><link data-head-react="true" href="android-app://com.mercadolibre/meli/search?go=https://listado.mercadolibre.com.ar/notebook" rel="alternate"/><link data-head-react="true" href="ios-app://463624852/meli/search?go=https://listado.mercadolibre.com.ar/notebook" re ...
# <link href="https://http2.mlstatic.com/frontend-assets/ml-web-navigation/ui-navigation/5.22.8/mercadolibre/navigation-desktop.css" onerror="(window['_pfl'] = window['_pfl'] || []).push(['css', this.href])" rel="stylesheet" type="text/css"/>
# <style>a.nav-skip-to-main-content{border:0;border-bottom-left-radius:4px;border-bottom-right-radius:4px;position:absolute;color:#fff;font-weight:100;text-decoration:none;text-align:center;background:#3484fa;top:0;left:0;z-index:999;cursor:pointer;height:0;padding:0;line-height:normal}a.nav-skip-to-main-content:focus{border:1px solid #3484fa;height:54px;padding:8px 8px}.nav-skip-to-main-content>.nav-skip-to-main-content__content{display:none}.nav-skip-to-main-content:focus>.nav-skip-to-main-content__content{display:block;padding:8px;border:1px solid #fff;border-radius:4px}</style>
# <style>.nav-search .nav-category:hover .nav-label-small{width:initial}.nav-search .nav-category label{-webkit-user-select:none}.nav-search .nav-category .nav-label-small{display:inline-block;text-overflow:ellipsis;overflow:hidden;white-space:nowrap;vertical-align:middle;width:58px}.nav-search .nav-category input[type=checkbox]:focus{outline:#9a9a9a dotted 1px}.mobile-view#mlCategory{top:unset;max-width:unset;text-align:left}.mobile-view#mlCategory input[type=checkbox]{vertical-align:unset}@media (max-width:768px){.nav-search .nav-category{display:none}}.nav-search .nav-category label .nav-category-icon{vertical-align:text-bottom}.nav-search .nav-category label .nav-icon-supermarket-logo{width:115px;height:18px}.mobile-view#mlCategory label .nav-icon-supermarket-logo{width:125px;height:22px;margin-left:1px;vertical-align:middle} .nav-icon-fulfillment-logo{width:45px;height:16px;vertical-align:middle;}</style>
# <link href="https://http2.mlstatic.com/frontend-assets/search-nordic/search.desktop.e3ef2b00.css" onerror="(window['_pfl'] = window['_pfl'] || []).push(['css', this.href])" rel="stylesheet" type="text/css"/>
# <script>
# (function(a,b){a.GoogleAnalyticsObject=b;a[b]=a[b]||function(){(a[b].q=a[b].q||[]).push(arguments)};a[b].l=1*new Date})(window,"meli_ga");
# meli_ga("set", "title", "app-search-nordic-nodejs-4.1.0");
# meli_ga("set", "page", "/SEARCH/LISTING/?q=notebook&c={'MLA1648':'Computaci\u00F3n'}");
# meli_ga("set", "dimension49", "MLA1384409092,MLA1329640432,MLA1369917527,MLA1400340120,MLA1417709326,MLA1417895600,MLA1134000806,MLA1393681384,MLA1120454113,MLA911480792,MLA1368349027,MLA1329318522,MLA1425610402,MLA1365414804,MLA1126009503,MLA1361660897,MLA1366945235,MLA1370911089,MLA1367129357,MLA1394042912,MLA1428866740,MLA1366215582,MLA1392405056,MLA1101060587,MLA1411670900,MLA1412480120,MLA1369952369,MLA1133446403,MLA1425622114,MLA1119054042,MLA1430045562,MLA1377503112,MLA1164297422,MLA1422195092,MLA1427558190,MLA1392261018,MLA1140620673,MLA1168312338,MLA1125369743,MLA1338579930,MLA1430334110,MLA1416066746,MLA1395744698,MLA1371994949,MLA1382771620,MLA1371177518,MLA1417529448,MLA1411517902,MLA1154219833,MLA1401869542,MLA1409567966,MLA1218793382,MLA1371518257,MLA1389179944");
# meli_ga("set", "dimension86", "MLA-NOTEBOOKS");
# meli_ga("set", "dimension117", "PDP+officialStore");
# meli_ga("set", "dimension145", "NONE");
# meli_ga("set", "dimension22", "20108");
# meli_ga("set", "dimension9", "NONE");
# meli_ga("set", "dimension23", "SEO-allowlist: in - SEARCH-noindex: false");
# meli_ga("set", "dimension21", "113");
# meli_ga("set", "dimension7", "MARKETPLACE");
# meli_ga("set", "dimension8", "CORE");
# meli_ga("set", "dimension48", "NONE");
# meli_ga("set", "dimension113", "7b8f3426-6ba6-4456-838f-d720c968b3c1");
# meli_ga("set", "dimension3", "{'MLA1648':'Computaci\u00F3n'}");
# meli_ga("set", "dimension4", "{'MLA1648':'Computaci\u00F3n','MLA430687':'Laptops y Accesorios'}");
# meli_ga("set", "dimension5", "{'MLA1648':'Computaci\u00F3n','MLA430687':'Laptops y Accesorios','MLA1652':'Notebooks'}");
# meli_ga("set", "contentGroup1", "/MARKETPLACE/SEARCH/LISTING/");
# meli_ga("set", "contentGroup2", "/CORE/SEARCH/LISTING/");
# meli_ga("set", "contentGroup3", "/MLA1648/SEARCH/LISTING/");
# meli_ga("set", "dimension1", "desktop");
# meli_ga("set", "dimension6", "listing");
# meli_ga("set", "dimension7", "MARKETPLACE");
# meli_ga("set", "dimension8", "CORE");
# meli_ga("send", "pageview");
# (function(d, win) {
#       win['GA-user-traceability-consent'] = true;
#       var i = d.createElement('iframe');
#       (i.frameElement || i).style.cssText = 'width: 0; height: 0; border: 0; position: absolute';
#       i.src = "about:srcdoc";
#       i.srcdoc="\<script\  src='https://http2.mlstatic.com/analytics/ga/mla-ml-analytics.min.js'>\</script></head><body><p>";
#       i.id = "GoogleAnalyticsIframe";
#       var w = d.getElementsByTagName('script')[0];
#       w.parentNode.insertBefore(i, w);
#       var doc = i.contentWindow.document;
#       var s = doc.createElement('script');
#       s.type = 'text/javascript';
#       s.text ='window.inDapIF = true;';
#       doc.documentElement.appendChild(s);
#     })(document, window);
#
# <style>
#   *:focus {
#     box-shadow: 0 0 0 2px #fff, 0 0 0 3px #2968C8, 0 0 0 5px rgba(65, 137, 230, 0.3);
#     outline: none;
#   }
#
#   *:focus-visible {
#     box-shadow: 0 0 0 2px #fff, 0 0 0 3px #2968C8, 0 0 0 5px rgba(65, 137, 230, 0.3);
#     outline: none;
#   }
#
#   *:focus:not(:focus-visible) {
#     box-shadow: none;
#     outline: none;
#   }
# </style></p><header class="nav-header nav-header-plus ui-navigation-v2" data-siteid="MLA" role="banner"><div class="nav-bounds nav-bounds-with-cart nav-bounds-with-cp"><div class="nav-header-plus-logo nav-area nav-top-area nav-left-area"><a aria-label="Ir al contenido principal" class="nav-skip-to-main-content" href="#root-app" id="nav-skip-to-main-content" role="button"><span class="nav-skip-to-main-content__content">Ir al contenido principal</span></a><a class="nav-logo" href="//www.mercadolibre.com.ar">Mercado Libre Argentina - Donde comprar y vender de todo</a></div><div class="nav-area nav-top-area nav-center-area"><form action="https://www.mercadolibre.com.ar/jm/search" class="nav-search" method="GET" role="search"><label class="nav-header-visually-hidden" for="nav-search-input">Ingresá lo que quieras encontrar</label><input aria-label="Ingresá lo que quieras encontrar" autocapitalize="off" autocomplete="off" autocorrect="off" class="nav-search-input" id="nav-search-input" maxlength="120" name="as_word" placeholder="Buscar productos, marcas y más…" spellcheck="false" type="text" value="notebook"/><p class="nav-category" id="mlCategory" title="Solo en Notebooks"><input id="categorySearch" name="as_categ_id" type="checkbox"/><label for="categorySearch">Solo en Notebooks</label></p><button class="nav-search-btn" type="submit"><div aria-label="Buscar" class="nav-icon-search" role="img"></div></button></form></div><div class="nav-area nav-top-area nav-right-area"><a class="exhibitor__picture" href="https://www.mercadolibre.com.ar/suscripciones/nivel-6#origin=banner-menu&amp;me.flow=-1&amp;me.bu=9&amp;me.audience=all&amp;me.content_id=bannermenu_n6_generico_v2&amp;me.component_id=banner_menu_web_ml&amp;me.logic=campaigns&amp;me.position=0&amp;me.bu_line=36"><img alt="Suscribite al nivel 6 con beneficios exclusivos" src="https://http2.mlstatic.com/D_NQ_957153-MLA69318147677_052023-OO.jpg" title="Suscribite al nivel 6 con beneficios exclusivos"/></a></div><div class="nav-header-plus-cp-wrapper nav-area nav-bottom-area nav-left-area"><a class="nav-header-cp-anchor" data-js="cp" data-modal-action="true" href="https://www.mercadolibre.com.ar/navigation/addresses-hub?go=https%3A%2F%2Flistado.mercadolibre.com.ar%2Fnotebook"><span class="nav-menu-link-cp"> Ingresa tu domicilio</span></a><div class="nav-menu-item"><a class="nav-menu-cp nav-menu-cp-guest" data-js="cp" data-modal-action="true" href="https://www.mercadolibre.com.ar/navigation/addresses-hub?go=https%3A%2F%2Flistado.mercadolibre.com.ar%2Fnotebook"><span class="nav-menu-link-cp"> Ingresa tu domicilio</span></a></div></div><div class="nav-area nav-bottom-area nav-center-area"><div class="nav-menu"><ul class="nav-menu-list"><li class="nav-menu-item"><a class="nav-menu-categories-link" data-js="nav-menu-categories-trigger" href="https://www.mercadolibre.com.ar/categorias#nav-header" rel="nofollow">Categorías</a></li><li class="nav-menu-item"><a class="nav-menu-item-link" href="https://www.mercadolibre.com.ar/ofertas#nav-header" rel="nofollow">Ofertas</a></li><li class="nav-menu-item"><a class="nav-menu-item-link" href="https://www.mercadolibre.com.ar/gz/home/navigation#nav-header" rel="nofollow">Historial</a></li><li class="nav-menu-item"><a class="nav-menu-item-link" href="https://www.mercadolibre.com.ar/ofertas/supermercadolibre#nav-header" rel="nofollow">Supermercado</a></li><li class="nav-menu-item"><a class="nav-menu-item-link" href="https://www.mercadolibre.com.ar/c/ropa-y-accesorios#nav-header" rel="nofollow">Moda</a></li><li class="nav-menu-item"><a class="nav-menu-item-link" href="https://www.mercadolibre.com.ar/publicar#nav-header" rel="nofollow">Vender</a></li><li class="nav-menu-item"><a class="nav-menu-item-link" href="https://www.mercadolibre.com.ar/ayuda#nav-header" rel="nofollow">Ayuda</a></li></ul></div></div><div class="nav-header-plus-menu-wrapper nav-area nav-bottom-area nav-right-area"><nav id="nav-header-menu"><a data-link-id="registration" href="https://w ...
# (function(w, r) {
#   w[r] = w[r] || function() {
#     (w[r].q = w[r].q || []).push(arguments)
#   }
# })(window,'melidata');
# (function(d,u) {
#   if (!document.getElementById("MelidataIframe")) {
#     var i = d.createElement('iframe');
#     (i.frameElement || i).style.cssText = "width: 0; height: 0; border: 0; position: absolute";
#     i.src = "about:srcdoc";
#     i.srcdoc="\<script\  src='" + u + "'>\</script>";
#     i.id = "MelidataIframe";
#     var t = d.getElementsByTagName('script')[0];
#     t.parentNode.insertBefore(i, t);
#     var doc = i.contentWindow.document;
#     var script = doc.createElement('script');
#     script.type = 'text/javascript';
#     script.text ='window.inDapIF = true;';
#     doc.documentElement.appendChild(script);
#   } else {
#     // This page is charged async via AJAX and inserted into another one who has
#     // already download melidata js lib =&gt; Just clean the track
#     melidata("clean");
#   }
# })(document,'https://http2.mlstatic.com/storage/melidata-js-sdk/js/3/0.3.48/melidata.min.js');
#
# melidata("add", "id", "ad69ce7e-b5c0-4c3a-9362-e5bf8499d24c");
# melidata("add", "server_id", "ad69ce7e-b5c0-4c3a-9362-e5bf8499d24c" );
# melidata("add", "application", {"version":"1.177.0","server_hostname":"","server_poolname":"","app_name":"","sdk_version":{"node_version":"6.1.0"},"business":"mercadolibre","site_id":"MLA","secured":{"encrypted":"247939ef31b1c3a818d35a4c097f564e:","signature":"eyJhbGciOiJIUzI1NiJ9.eyJ1aWQiOiJlNjcwMjE4OS00ZjJhLTRmZjMtYmNmMC0wNjgyNTFlZTdiZjAiLCJzaXRlX2lkIjoiTUxBIiwicGxhdGZvcm0iOiIvd2ViL2Rlc2t0b3AifQ.WW2Q5VyMT4Z7iZPSsxMPW0NUkNW-nARQCa9D1zhFeoA"}});
# melidata("add", "user", {"uid":"e6702189-4f2a-4ff3-bcf0-068251ee7bf0","user_tags":[],"privacy_consents":{"advertising":true,"traceability":true}});
# melidata("add", "device", {"platform":"/web/desktop","user_agent":"Mozilla/5.0"});
# melidata("add", "platform", {"http":{"cookies":{},"headers":{"host":"listado.mercadolibre.com.ar","x-request-id":"e6702189-4f2a-4ff3-bcf0-068251ee7bf0","x-d2id":"e6702189-4f2a-4ff3-bcf0-068251ee7bf0","x-device-js":"true","x-platform":"ml"},"http_url":"https://listado.mercadolibre.com.ar/notebook"}});
# melidata("add", "experiments", {"searchAdsAdnProvider":"13391","search/navigation-by-models":"DEFAULT","mclics/pseudo-search-pads-buybox":"7708","frontend/assetsCdnDomainMLU":"DEFAULT","search/search-alert":"15520","mclics/show-pads-search-list":"5146","search/external-installments":"14567","frontend/assetsCdnDomainMLA":"DEFAULT","mclics/search-list-ad-algorithm":"16026","mclics/show-pads-global":"5176","search/zrp-disclaimer":"DEFAULT","mclics/rolling-layout":"20432","search/no-interest-experiment":"15657"});
# melidata("add", "experiments_timestamp", "null");
# melidata("add", "event_data", {"query":"notebook","limit":50,"offset":0,"total":20108,"category_id":"MLA1652","domain":"MLA-NOTEBOOKS","category_path":["MLA1648","MLA430687","MLA1652"],"sort_id":"relevance","filters":{"category":"MLA1652"},"displayed_filters":[{"id":"shipping_highlighted_fulfillment","name":"Tipo de entrega","type":"highlighted","position":1,"values_quantity":1,"values":["fulfillment"]},{"id":"shipping_cost_highlighted","name":"Costo de envío","type":"highlighted","position":2,"values_quantity":1,"values":["free"]},{"id":"installments_highlighted_campaign_ahora","name":"Financiación","type":"highlighted","position":3,"values_qu
# melidata("send", "view", {
#   path: "/search",
#   data: {}
# }, "melidata");
# <script>
# (function(win, doc){
#   function loadScripts (s) {
#     if (!s || !s.length) return;
#     s = s.slice(0);
#     var h = doc.head || doc.getElementsByTagName('head')[0];
#     var cbStack = {}; var cbChild = {};
#
#     for (var i = 0; i < s.length; i++) {
#       var c = s[i];
#       var t = doc.createElement('script');
#
#       if (typeof c.s === 'function') {
#         t.textContent = '(' + c.s + ').apply(window);';
#       } else {
#         t.async = false;
#         t.defer = true;
#         t.crossOrigin = 'anonymous';
#         if (c.props){
#           for (var key in c.props){
#             t[key] = c.props[key];
#           }
#         }
#         if (c.id) t.id = c.id;
#
#         if (c.s) t.src = c.s;
#         var x = t.src;
#         cbStack[x] = [];
#         while(s[i+1] && typeof s[i+1].s === 'function') {
#           cbStack[x].push(s[i+1].s);
#           i++;
#         }
#         if (typeof c.c === 'function') {
#           cbChild[x] = c.c
#         } else if (c.c) {
#           t.textContent = c.c;
#         }
#         t.onerror = function(err) {
#           cbStack[err.target.src] && cbStack[err.target.src].forEach(function(cb){ (cb).apply(window) });
#
#           var perfillNamespace = '_pfl';
#           (window[perfillNamespace] = window[perfillNamespace] || []).push(['script', err.target.src])
#         }
#         t.onload = function(e) {
#           cbChild[e.target.src] && (cbChild[e.target.src]).apply(window);
#           cbStack[e.target.src] && cbStack[e.target.src].forEach(function(cb){ (cb).apply(window) });
#         }
#       }
#       h.appendChild(t);
#     }
#   }
#   loadScripts([{s:function(){window.__NAVIGATION_PRELOADED_STATE__ = {"application":"search-nordic","siteId":"MLA","domain":"mercadolibre.com.ar"};},props:{"on":"now","preload":false,"type":"function"}},{s:function(){"use strict";function a(a){if(a.analytics&&"undefined"!=typeof meli_ga&&meli_ga("send",{hitType:a.analytics.hitType,eventCategory:a.analytics.category,eventAction:a.analytics.action,eventLabel:a.analytics.label}),a.melidata&&"undefined"!=typeof melidata){var t=a.melidata.data;melidata("cleanAndSend",a.melidata.type,{path:a.melidata.path,data:t})}}window.__navigation_tracking__=function(t,e,n){var i=document.querySelector(t);i&&i.addEventListener(e,(function(){a(n)}))},window.__navigation_track__=a;
# },props:{"on":"now","preload":false,"type":"function"}},{s:function(){"use strict";window.__navigation_tracking__("#nav-skip-to-main-content","click",{analytics:{category:"SKIP_TO_MAIN_CONTENT",action:"NAVIGATION",label:window.__NAVIGATION_PRELOADED_STATE__.application,hitType:"event"},melidata:{path:"/navigation/skip-to-main-content",type:"event",data:{app:window.__NAVIGATION_PRELOADED_STATE__.application}}});
# },props:{"on":"now","preload":false,"type":"function"}},{s:function(){"use strict";window.__navigation_tracking__("[data-js=cp]","click",{analytics:{category:"CURRENT_LOCATION",action:"NAVIGATION",label:window.__NAVIGATION_PRELOADED_STATE__.application,hitType:"event"},melidata:{path:"/current_location/navigation/pick",data:{app:window.__NAVIGATION_PRELOADED_STATE__.application},type:"event"}});
# },props:{"on":"now","preload":false,"type":"function"}},{s:function(){(function() {
#     var defaults = {
#         imageLoadClassName: 'lazy-loadable', // 'lazy-loadable' || 'onload-loadable'
#         options: {
#             rootMargin: '360px',
#             loadMode: 'lazy' // 'lazy' || 'onload'
#         }
#     };
#     var dataSrcKey = 'data-src';
#     var dataSrcFallbackKey = 'data-src-fallback';
#     var dataSrcSetKey = 'data-srcset';
#
#     // IntersectionObserver has partial support in chrome <= 57 (https://caniuse.com/#feat=intersectionobserver)
#     var supportIntersectionObserver = 'IntersectionObserver' in window && 'IntersectionObserverEntry' in window && 'isIntersecting' in window.IntersectionObserverEntry.prototype;
#
#   function mergeOptions(target, source) {
#     var list = [target, source];
#     var cloned = {};
#
#     for (var i = 0; i <= list.length; i++) {
#       if (typeof list[i] === 'object' && list[i]) {
#         for (var prop in list[i]) {
#           cloned[prop] = list[i][prop];
#         }
#       }
#     }
#     return cloned;
#   }
#
#   function imageLazyLoading(imageLoadClassName, options) {
#         if (!imageLoadClassName && options && options.loadMode === 'onload') {
#           imageLoadClassName = 'onload-loadable';
#         }
#         imageLoadClassName = imageLoadClassName || defaults.imageLoadClassName;
#
#         options = mergeOptions(defaults.options, options);
#
#         var lazyImages = [].slice.call(document.querySelectorAll('.' + imageLoadClassName));
#
#         function loadImages(img) {
#             function setSource(attr, srcKey, srcFallbackKey) {
#                 if (img.hasAttribute(srcKey)) {
#                     var dataSrc = img.getAttribute(srcKey);
#                     if (srcFallbackKey && img.hasAttribute(srcFallbackKey)) {
#                       var dataSrcFallback = img.getAttribute(srcFallbackKey);
#                       img.onload = function() {
#                         img.removeAttribute(srcFallbackKey);
#                       }
#                       img.onerror = function() {
#                         this.src = dataSrcFallback;
#                         this.srcset = dataSrcFallback;
#                         img.removeAttribute(srcFallbackKey);
#                         img.onerror = null;
#                       };
#                     }
#                     img.setAttribute(attr, dataSrc);
#                     img.removeAttribute(srcKey);
#                 }
#             }
#
#             setSource('src', dataSrcKey, dataSrcFallbackKey);
#             setSource('srcset', dataSrcSetKey);
#
#             img.classList.remove(imageLoadClassName);
#
#             if (img.classList.length < 1) {
#                 img.removeAttribute('class');
#             }
#         }
#
#         function loadAllImages() {
#           lazyImages.forEach(function(image) {
#                 loadImages(image);
#             });
#         }
#
#         if (supportIntersectionObserver && options.loadMode === 'lazy') {
#             var lazyImageObserver = new IntersectionObserver(function(entries, observer) {
#                 entries.forEach(function(entry) {
#                 if (entry.isIntersecting) {
#                     var lazyImage = entry.target;
#                     loadImages(lazyImage);
#                     lazyImageObserver.unobserve(lazyImage);
#                 }
#                 });
#             }, options);
#
#             lazyImages.forEach(function(lazyImage) {
#                 lazyImageObserver.observe(lazyImage);
#             });
#
#             window.lazyImageObserver = lazyImageObserver;
#
#         } else if ((!supportIntersectionObserver && options.loadMode === 'lazy') || options.loadMode === 'onload') {
#             if (document.readyState === 'complete') {
#                 loadAllImages();
#             } else {
#                 window.addEventListener('load', function() {
#                     loadAllImages();
#                 });
#             }
#         }
#     }
#
#     function initLazyLoading() {
#       imageLazyLoading();
#       imageLazyLoading('onload-loadable', { loadMode: 'onload' });
#     }
#
#     window.imageLazyLoading = imageLazyLoading;
#     initLazyLoading();
# }());
# },props:{"on":"now","inline":true}}]);
#   var scripts = [{s:function(){(function(){/*! For license information please see cookie-consent-banner.js.LICENSE */
# var ccb=function(e){var t={};function n(o){if(t[o])return t[o].exports;var i=t[o]={i:o,l:!1,exports:{}};return e[o].call(i.exports,i,i.exports,n),i.l=!0,i.exports}return n.m=e,n.c=t,n.d=function(e,t,o){n.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:o})},n.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},n.t=function(e,t){if(1&t&&(e=n(e)),8&t)return e;if(4&t&&"object"==typeof e&&e&&e.__esModule)return e;var o=Object.create(null);if(n.r(o),Object.defineProperty(o,"default",{enumerable:!0,value:e}),2&t&&"string"!=typeof e)for(var i in e)n.d(o,i,function(t){return e[t]}.bind(null,i));return o},n.n=function(e){var t=e&&e.__esModule?function(){return e.default}:function(){return e};return n.d(t,"a",t),t},n.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},n.p="",n(n.s=1)}([function(e,t){e.exports={sendMelidataTrack:function(e,t){"undefined"!=typeof melidata&&melidata("cleanAndSend",e,t)}}},function(e,t,n){e.exports=n(2)},function(e,t,n){function o(e){return(o="function"==typeof Symbol&&"symbol"==typeof Symbol.iterator?function(e){return typeof e}:function(e){return e&&"function"==typeof Symbol&&e.constructor===Symbol&&e!==Symbol.prototype?"symbol":typeof e})(e)}function i(e,t){var n=Object.keys(e);if(Object.getOwnPropertySymbols){var o=Object.getOwnPropertySymbols(e);t&&(o=o.filter((function(t){return Object.getOwnPropertyDescriptor(e,t).enumerable}))),n.push.apply(n,o)}return n}function r(e){for(var t=1;t<arguments.length;t++){var n=null!=arguments[t]?arguments[t]:{};t%2?i(Object(n),!0).forEach((function(t){a(e,t,n[t])})):Object.getOwnPropertyDescriptors?Object.defineProperties(e,Object.getOwnPropertyDescriptors(n)):i(Object(n)).forEach((function(t){Object.defineProperty(e,t,Object.getOwnPropertyDescriptor(n,t))}))}return e}function a(e,t,n){return(t=function(e){var t=function(e,t){if("object"!==o(e)||null===e)return e;var n=e[Symbol.toPrimitive];if(void 0!==n){var i=n.call(e,t||"default");if("object"!==o(i))return i;throw new TypeError("@@toPrimitive must return a primitive value.")}return("string"===t?String:Number)(e)}(e,"string");return"symbol"===o(t)?t:String(t)}(t))in e?Object.defineProperty(e,t,{value:n,enumerable:!0,configurable:!0,writable:!0}):e[t]=n,e}var s=n(3),c=n(4).bannerOptOutModalEvents,d=n(8),l=d.createBannerEventListeners,u=d.removeBannerWindowEventListeners,f=n(0).sendMelidataTrack;e.exports=function(e,t,n,o,i,a){var d=arguments.length>6&&void 0!==arguments[6]?arguments[6]:"cookie-consent-banner-opt-out",v=arguments.length>7?arguments[7]:void 0,h=arguments.length>8?arguments[8]:void 0,p=d,m="cookie-consent-snackbar--success",y="cookie-consent-snackbar--error",b="cookies-banner-top-content",g=function(t,n){var o=(n||e).getElementsByClassName(t);if(0===o.length)throw new Error("No element with class ".concat(t," is present"));if(1!==o.length)throw new Error("More than one element with class ".concat(t," is present"));return o[0]},w=function(e){return e.parentNode.removeChild(e)},_=function(){try{return g(b,g(p))}catch(e){return null}},E=function(){return window.onCookieConsentBannerClosed&&window.onCookieConsentBannerClosed()},S=function(e){e.classList.add("cookie-consent-snackbar--collapsed"),setTimeout((function(){w(e),E()}),400)},k=function(){var e=g(m),t=g(y);w(e),w(t)},C=function(e){var t=e.toShow,n=e.toHide,o=e.topContentContainer,i=e.hideTimeoutInMs,r=g(n);w(r);var a=g(t);o&&a.appendChild(o),a.classList.remove("cookie-consent-snackbar--hidden"),setTimeout((function(){return a.classList.remove("cookie-consent-snackbar--collapsed")}));var s=null;i>0&&(s=setTimeout((function(){S(a)}),i)),g("cookie-consent-snackbar__close",a).addEventListener("click",(function(){clearTimeout(s),S(a)}))},L=function(e){var t=(h||{}).successSnackbar||{},n=t.canShow,o=t.hideTimeoutInMs,i=void 0===o?0:o;if(!1===n)return k(),void E();C({toShow:m,toHide:y,topContentContainer:e,hideTimeoutI ...
# ccb(document,{"advertising":true,"traceability":true},null,[{"userId":null,"cookieName":"cookiesPreferencesNotLogged","path":"/","domain":"mercadolibre.com.ar","secure":true,"sameSite":"none","maxAge":31556900}],"bottomOptOut",{"closeElements":[]},"cookie-consent-banner-opt-out",{"id":"js-modal-cookie-consent-banner-opt-out","wrapperClassName":"cookie-consent-banner-opt-out__modal-wrapper","openButton":"cookie-consent-banner-opt-out__action--key-customize","iframeUrl":"https://www.mercadolibre.com.ar/privacy-preferences/cookies","saveText":"Guardar","i18n":{"title":"Preferencias de cookies","close":"Cerrar"}},{"successSnackbar":{"canShow":false,"hideTimeoutInMs":8000},"errorSnackbar":{"canShow":true,"hideTimeoutInMs":8000}});})()},props:{"on":"load","preload":false,"type":"function"}},{s:function(){
#       !function(n,e){n.mitt=e()}(this,function(){function n(n){return n=n||Object.create(null),{on:function(e,t){(n[e]||(n[e]=[])).push(t)},off:function(e,t){n[e]&&n[e].splice(n[e].indexOf(t)>>>0,1)},emit:function(e,t){(n[e]||[]).map(function(n){n(t)}),(n["*"]||[]).map(function(n){n(e,t)})}}}return n});
#       window.freya = mitt();
#     },props:{"on":"load","preload":false,"type":"function"}},{s:"https://http2.mlstatic.com/frontend-assets/ml-web-navigation/widgets/5.22.8/searchbox.js",props:{"on":"load"},c:function(){
#       if (window.Searchbox) {
#         new window.Searchbox('.nav-search-input', {
#           platformId: 'ML',
#           siteId: 'MLA',
#           siteDomain: 'mercadolibre.com.ar',
#           limit: 6,
#           searchEndpoint: 'https://listado.mercadolibre.com.ar/$query',
#           categoryEndpoint: 'https://listado.mercadolibre.com.ar/computacion/laptops-accesorios/notebooks/$query_NoIndex_True',
#           categoryCheckbox: document.getElementById('categorySearch'),
#           loggedIn: false,
#
#           bus: window.freya,
#           deviceType: 'desktop'
#         });
#       }
#     }},{s:"https://http2.mlstatic.com/frontend-assets/ml-web-navigation/widgets/5.21.3/modal.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/ml-web-navigation/widgets/5.21.22/onboarding-cp.js",props:{"on":"load"},c:function(){(function () {
#           new window.OnboardingCP({
#             bus: window.meli,
#             isNewBuyer: true,
#             isMobile: undefined,
#             trigger: '.nav-menu-cp',
#             locale: 'es_AR',
#             domain: 'mercadolibre.com.ar',
#             siteId: 'MLA',
#             linkCPRef: 'undefined',
#             isInferred: false,
#             navDabClosed:undefined,
#             navDabLastClosed:undefined,
#           });
#         }());
#     }},{s:"https://http2.mlstatic.com/frontend-assets/ml-web-navigation/widgets/5.22.8/categories.js",props:{"on":"load"},c:function(){
#       (function(win, freya) {
#         if (win.CategoriesWidget && typeof freya !== 'undefined') {
#           new CategoriesWidget({
#             bus: freya,
#             endpoint: '//www.mercadolibre.com.ar/menu/departments?zipcode=',
#           });
#         }
#       })(window, window.freya);
#     }},{s:function(){
#           if (window.Cart) {
#             new window.Cart({
#               trigger: document.getElementById('nav-cart'),
#               isHover: true,
#               small: true,
#               carts: undefined,
#               baseUrl: 'https://www.mercadolibre.com.ar/gz/cart/v2',
#               bus: freya,
#             });
#           }
#         },props:{"on":"load","preload":false,"type":"function"}},{s:"https://http2.mlstatic.com/frontend-assets/ml-web-navigation/widgets/5.22.11/CartWidget.js",props:{"on":"load"},c:function(){
#           if (window.CartWidget) {
#             new window.CartWidget({
#               element: document.getElementById('nav-cart'),
#               endpoints: {
#                 get: 'https://www.mercadolibre.com.ar/gz/cart/v2/info/header',
#                 post: 'https://www.mercadolibre.com.ar/gz/cart/v2/api/item',
#               },
#               link: 'https://www.mercadolibre.com.ar/gz/cart/v2',
#               isMobile: false,
#               bus: freya,
#               locale: 'es',
#             });
#           }
#         }},{s:"https://http2.mlstatic.com/frontend-assets/ml-web-navigation/widgets/5.21.3/snackbar.js",props:{"on":"load"},c:function(){
#         (function (win, freya) {
#           if (win.SnackbarWidget && typeof freya !== 'undefined') {
#             new win.SnackbarWidget({
#               bus: freya,
#             });
#           }
#         }(window, window.freya));
#         }},{s:function(){"use strict";!function(e,t){var s=t.getElementById("nav-footer-access-switch"),a=t.querySelector(".nav-footer-access");function c(){var s=setInterval((function(){try{var a=Math.max(t.body.scrollHeight,t.body.offsetHeight,t.documentElement.clientHeight,t.documentElement.scrollHeight,t.documentElement.offsetHeight),c=e.pageYOffset||t.documentElement.scrollTop||t.body.scrollTop||0;e.innerHeight+c>=a?clearInterval(s):e.scrollBy(0,20)}catch(e){clearInterval(s)}}),15)}e.addEventListener&&s&&s.addEventListener("click",(function(){"nav-footer-access nav-footer-access-collapsed"===a.className?(setTimeout(c,200),a.classList.remove("nav-footer-access-collapsed"),a.classList.add("nav-footer-access-expanded"),s.setAttribute("aria-expanded","true")):(a.classList.remove("nav-footer-access-expanded"),a.classList.add("nav-footer-access-collapsed"),s.setAttribute("aria-expanded","false"))}))}(window,document);
# },props:{"on":"load","preload":false,"type":"function"}},{s:"https://http2.mlstatic.com/storage/tag-manager/google-gtag-search-mla.js",props:{"on":"load"}},{s:function(){"use strict";(function(a){var b=a.location.hostname.substr(a.location.hostname.indexOf("."),a.location.hostname.length);if(-1!==b.indexOf("mercadolibre")||-1!==b.indexOf("mercadolivre")||-1!==b.indexOf("mercadopago")){var c="https://matt"+b,d=a.location.href;if(c=c.concat("?go=").concat(encodeURIComponent(d)),navigator&&navigator.sendBeacon)status=navigator.sendBeacon(c);else{var e=new XMLHttpRequest;e.open("GET",c),e.send()}}})(window);},props:{"on":"load","inline":true}},{s:function(){
#           window.__PRELOADED_STATE__ =
#       {"site":"ML","siteId":"MLA","cookies":{},"lowEnd":false,"deviceType":"desktop","country":{"id":"AR","name":"Argentina","locale":"es_AR","currency_id":"ARS","decimal_separator":",","thousands_separator":".","time_zone":"GMT-03:00","geo_information":{"location":{"latitude":-38.416096,"longitude":-63.616673}},"states":[{"id":"AR-B","name":"Buenos Aires"},{"id":"AR-C","name":"Capital Federal"},{"id":"AR-K","name":"Catamarca"},{"id":"AR-H","name":"Chaco"},{"id":"AR-U","name":"Chubut"},{"id":"AR-W","name":"Corrientes"},{"id":"AR-X","name":"Córdoba"},{"id":"AR-E","name":"Entre Ríos"},{"id":"AR-P","name":"Formosa"},{"id":"AR-Y","name":"Jujuy"},{"id":"AR-L","name":"La Pampa"},{"id":"AR-F","name":"La Rioja"},{"id":"AR-M","name":"Mendoza"},{"id":"AR-N","name":"Misiones"},{"id":"AR-Q","name":"Neuquén"},{"id":"AR-R","name":"Río Negro"},{"id":"AR
e=mclics%2Fpseudo-search-pads-buybox%2B7708%2Cmclics%2Fsearch-list-ad-algorithm%2B16026%2Cmclics%2Frolling-layout%2B20432%2Cmclics%2Fshow-pads-global%2B5176%2Cmclics%2Fshow-pads-search-list%2B5146&rb=x","landing":"https:\u002F\u002Fads.mercadolibre.com.ar\u002FproductAds?ui_version=v2&utm_source=search_result_placement&utm_medium=link&utm_campaign=engagement","show_google_ads":true,"ui":{"version":"v2","font_color":"#3483FA","font_size":12}},"analytics_track":{"dimensions":{"itemId":"MLA1384409092,MLA1329640432,MLA1369917527,MLA1400340120,MLA1417709326,MLA1417895600,MLA1134000806,MLA1393681384,MLA1120454113,MLA911480792,MLA1368349027,MLA1329318522,MLA1425610402,MLA1365414804,M ...
#         },props:{"on":"load","preload":false,"type":"function"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/polyfill.f4dafdd6.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/search.desktop.ced687e3.js",props:{"on":"load"}},{s:function(){
#         var trackMclics = document.createElement('img');
#         trackMclics.src = 'https://print1.mercadoclics.com/mclics/v2/prints/external/MLA/count?d=xQkXnDjJzHE3t9sMIHvg5jOrT0TJy3Mr4NS9QZCSSPNEPgJK%2FqjNRobGBof%2BAjATM2UNJQO%2F02GpXK%2BwUOkxO%2BINIkN1oBv0%2FJOhE8z3x%2BSV20jzP57ciaq2Rc770A2RTqj6x4RUmlTG7zT8G3cEyC40b2xCk6TAmDOU%2FYz%2FqSott8nBcMYJSCdKP5LjR6fghAnFaYsQqt5n54Zdw1vqPaikU4h6zW3%2FcBTzEfOhbhWw4JbbzXnpMlhCLtHF8KjlA%2BqqXtnhStV9LPc88z2cr7izhcad1axDFowdPBjNqNov70y6IvNxAy6XD7vSDa6cKflhC%2FjOgvaXbR5s2HqI26nQ52MgF4OSYmItKJ9FkWEaIFYoEoSqlg1ef0VNYAAyU1QUTxj4dZ1VZcN2BvNsVXvCbMxQ%2FqmzvvP4IPjVyxbNWVE4s%2FhzcGXqS9%2BI5jsUshFX%2Bo0e4nVqJIHwxvPhEnx19KCJQyYGYJcqp%2F53f0OKNFkUkOHElGwNP%2FGhopLWiO9Ku9FEHhdKAypyEDuAck1qfJEf2BTkYqQ%3D&e=mclics%2Fpseudo-search-pads-buybox%2B7708%2Cmclics%2Fsearch-list-ad-algorithm%2B16026%2Cmclics%2Frolling-layout%2B20432%2Cmclics%2Fshow-pads-global%2B5176%2Cmclics%2Fshow-pads-search-list%2B5146&rb=x';
#       },props:{"on":"load","preload":false,"type":"function"}},{s:"https://http2.mlstatic.com/frontend-assets/adn-frontend-library/adn-script.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/frontend-viewability/viewability-script.0.0.4.js",props:{"on":"load"}},{s:function(){
#
#
#      var mktconfig = {
#     'selector' : 'searchResults',
#     'results': 'MLA1384409092,MLA1329640432,MLA1369917527,MLA1400340120,MLA1417709326',
#     'categories': 'MLA1652,MLA1652,MLA1652,MLA1652,MLA1652',
#     'siteId' : 'MLA',
#     'd2id': '',
#     'query': 'notebook',
#     'platform' : 'STD'
#         }
#
#         var Search = Search || {};
#
#
#         ;(function (Search, win, doc) {
#
#           function MarketingTags(options) {
#             this.platform = options.platform || '';
#             this.siteId = options.siteId || '';
#             this.items = options.results || [];
#             this.categories = options.categories || [];
#             this.d2id = options.d2id;
#             this.query = options.query;
#
#             if (!this.items || !this.platform || !this.siteId || !this.categories) { throw new Error('MarketingTags: error in incoming params')}
#
#               this.init();
#
#               return this;
#
#           };
#
#           MarketingTags.prototype.init = function () {
#             var data = {}, categoriesIds = [];
#
#             if (this.items) {
#               data.items = this.items;
#               categoriesIds = this.unique(this.categories);
#
#               if(categoriesIds.length == 1){
#                 data.categoryId = categoriesIds
#               }
#
#               if (this.d2id) {
#                 data.d2id = this.d2id
#               }
#
#               if (this.query) {
#                 data.query = this.query;
#               }
#
#               this.start(data);
#               this.createIframe();
#             }
#           };
#
#           MarketingTags.prototype.createIframe = function () {
#             var iframe = doc.createElement("iframe"),
#                   scriptTag = doc.getElementsByTagName('script')[0],
#               elem = iframe.frameElement || iframe;
#
#                 elem.style.width = 0;
#               elem.style.height = 0;
#               elem.style.border = 0;
#               elem.style.position = 'absolute';
#
#
#                 iframe.src = this.url;
#                 scriptTag.parentNode.insertBefore(iframe, scriptTag);
#           };
#
#           MarketingTags.prototype.start = function (data) {
#             var millisecondsInMinute = 60000
#             var minuteInPartition = 60 * 5
#             var currentMilliseconds = new Date().getTime()
#             var currentSeconds = parseInt(currentMilliseconds / millisecondsInMinute)
#             var timeHash = parseInt(currentSeconds/minuteInPartition)*minuteInPartition
#
#             this.url = "https://http2.mlstatic.com/storage/tag-manager/" + this.siteId + ".html?timehash="+ timeHash +"&platform=" + this.platform + "#" + JSON.stringify(data);
#
#           };
#
#           MarketingTags.prototype.unique = function(array){
#               var tmp = {},
#                 out = [];
#               for(var i = 0, n = array.length; i < n; ++i){
#                   if(!tmp[array[i]]) { tmp[array[i]] = true; out.push(array[i]); }
#               }
#               return out;
#           }
#
#             Search.MarketingTags = MarketingTags;
#
#         })(Search, window, document);
#
#           new Search.MarketingTags(mktconfig);
#     },props:{"on":"load","preload":false,"type":"function"}},{s:function(){
#           window.qualtricsEmbeddedData = {"user_id":undefined,"is_identifier":false,"category_id":"MLA1652","flow_type":undefined};
#       },props:{"on":"load","inline":true,"preload":false,"type":"function"}},{s:function(){
#     (function () {
#       var g = function (e, h, f, g) {
#         this.get = function (a) {
#           for (var a = a + '=', c = document.cookie.split(';'), b = 0, e = c.length; b < e; b++) {
#             for (var d = c[b]; ' ' == d.charAt(0); ) d = d.substring(1, d.length);
#             if (0 == d.indexOf(a)) return d.substring(a.length, d.length);
#           }
#           return null;
#         };
#         this.set = function (a, c) {
#           var b = '',
#             b = new Date();
#           b.setTime(b.getTime() + 6048e5);
#           b = '; expires=' + b.toGMTString();
#           document.cookie = a + '=' + c + b + '; path=/; ';
#         };
#         this.check = function () {
#           var a = this.get(f);
#           if (a) a = a.split(':');
#           else if (100 != e)
#             'v' == h && (e = Math.random() >= e / 100 ? 0 : 100),
#               (a = [h, e, 0]),
#               this.set(f, a.join(':'));
#           else return !0;
#           var c = a[1];
#           if (100 == c) return !0;
#           switch (a[0]) {
#             case 'v':
#               return !1;
#             case 'r':
#               return (c = a[2] % Math.floor(100 / c)), a[2]++, this.set(f, a.join(':')), !c;
#           }
#           return !0;
#         };
#         this.go = function () {
#           if (this.check()) {
#             var a = document.createElement('script');
#             a.type = 'text/javascript';
#             a.src = g;
#             document.body && document.body.appendChild(a);
#           }
#         };
#         this.start = function () {
#           var t = this;
#           'complete' !== document.readyState
#             ? window.addEventListener
#               ? window.addEventListener(
#                   'load',
#                   function () {
#                     t.go();
#                   },
#                   !1
#                 )
#               : window.attachEvent &&
#                 window.attachEvent('onload', function () {
#                   t.go();
#                 })
#             : t.go();
#         };
#       };
#       try {
#         new g(
#           100,
#           'r',
#           'QSI_S_ZN_efi6I3nkl8bGcTA',
#           'https://znefi6i3nkl8bgcta-mercadolibre.siteintercept.qualtrics.com/SIE/?Q_ZID=ZN_efi6I3nkl8bGcTA'
#         ).start();
#       } catch (i) {}
#     })();
#     },props:{"on":"load","inline":true,"preload":false,"type":"function"}},{s:function(){
#     (function(h,o,t,j,a,r){
#       h.hj= h.hj || function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#       h._hjSettings={hjid:414773,hjdebug:false,hjsv:5};
#       a=o.getElementsByTagName('head')[0];
#       r=o.createElement('script');r.async=1;
#       r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#       a.appendChild(r);
#     })(window,document,'//static.hotjar.com/c/hotjar-','.js?sv=');
#     hj('tagRecording', ["search_nordic","user_type: normal"]);
#     hj('trigger', 'search_nordic');
#     },props:{"on":"load","type":"function"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/framework.5b273319.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/lib-62e29eec.9b8dcd16.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/2983.6ad447dd.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/4551.e15eb707.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/3369.81b64006.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/5165.5bdfd745.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/5438.4f9006d9.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/7522.9af293f7.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/2411.fa7d0f8e.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/8751.d02a1c95.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/8880.f607b761.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/134.54c25af3.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/2577.9d42e0f2.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/9892.c0f85434.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/4712.5b81eb6c.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/4149.e0aa7d91.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/4231.efd2421d.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/chunk-header-exhibitor.57104e5a.js",props:{"on":"load"}},{s:"https://http2.mlstatic.com/frontend-assets/search-nordic/chunk-listing-disclaimer.db9d22ad.js",props:{"on":"load"}}];
#   if (doc.readyState === 'complete') {
#     loadScripts(scripts);
#   } else {
#     win.addEventListener('load', function(){ loadScripts(scripts); });
#   }
# })(window, document);</script></body></html>

# %%
# Definimos un dict en blanco para cargarle los resultados en cada iteración
# i es el identificador del producto como clave principal del diccionario
dict = {}
i = 0

# Obtenemos el cuadro principal de los resultados, donde se encuentran divs mas pequeños con 
# la especificación de cada producto
item_list = soup.find_all('div', class_="ui-search-result__content-wrapper shops__result-content-wrapper")

# Ahora en item vamos guardando cada div de cada producto, y le extraemos las variables de principal interés
for item in item_list:
    product_name = item.find('h2')
    product_name = product_name.text
    product_price_symbol = item.find('span', {'class' : 'price-tag-symbol'})
    product_price_number = item.find('span', {'class' : 'price-tag-fraction'})
    product_discount = item.find('span', {'class' : 'ui-search-price__discount shops__price-discount'})
    product_cuotas = item.find('span', {'class' : 'ui-search-item__group__element shops__items-group-details ui-search-installments ui-search-color--LIGHT_GREEN'})
    product_shipping = item.find('p', {'class' : 'ui-search-item__shipping ui-search-item__shipping--free shops__item-shipping-free'}).text
    product_reviews = item.find('span', {'class' : 'ui-search-reviews__amount'})
    product_seller = item.find('p', {'class' : 'ui-search-official-store-label ui-search-item__group__element shops__items-group-details ui-search-color--GRAY'})
    product_link = item.find('a').get('href')
    
#   If find_all() can’t find anything, it returns an empty list. If find() can’t find anything, it returns None
    
#   .text is just a property that calls get_text. Therefore, calling get_text without arguments is 
#   the same thing as .text. However, get_text can also support various keyword arguments to change how 
#   it behaves (separator, strip, types). If you need more control over the result, 
#   then you need the functional form.


#   Sacamos el text de las etiquetas

    if product_price_symbol is not None:
        product_price_symbol = product_price_symbol.get_text()
    if product_price_number is not None:
        product_price_number = product_price_number.get_text()
    if product_discount is not None:
        product_discount = product_discount.get_text()
    if product_cuotas is not None:
        product_cuotas = product_cuotas.get_text()
    if product_reviews is not None:
        product_reviews = product_reviews.get_text()
    if product_seller is not None:
        product_seller = product_seller.get_text()
    
# Guardamos los resultados a un diccionario anidado.
    dict.update({i:{
        'product_name': product_name,
        'price_tag_symbol': product_price_symbol,
        'product_price_number': product_price_number,
        'product_discount': product_discount,
        'product_cuotas': product_cuotas,
        'product_shipping': product_shipping,
        'product_reviews': product_reviews,
        'product_seller': product_seller,
        'product_link': product_link
    }})

# Aumentamos el valor de i, para que el próximo producto tenga un id mayor al corriente    
    i= i + 1

# %%
dict
# Out:
# {0: {'product_name': 'Notebook Asus Vivobook 15 X1502 azul 15.6", Intel Core i5 1240P  8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 80EUs Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '449.999',
#   'product_discount': '18% OFF',
#   'product_cuotas': 'Mismo precio en 6 cuotas de $61.499',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '122',
#   'product_seller': 'Vendido por ASUS',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-vivobook-15-x1502-azul-156-intel-core-i5-1240p-8gb-de-ram-256gb-ssd-intel-iris-xe-graphics-g7-80eus-windows-11-home/p/MLA19710772?pdp_filters=category:MLA1652#searchVariation=MLA19710772&position=1&search_layout=stack&type=product&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  1: {'product_name': 'Notebook Asus I7 Vivobook 15 512gb Ssd 16gb Ram 4,7 Ghz',
#   'price_tag_symbol': '$',
#   'product_price_number': '644.999',
#   'product_discount': '15% OFF',
#   'product_cuotas': 'Mismo precio en 6 cuotas de $91.374',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '130',
#   'product_seller': 'Vendido por ASUS',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-i7-vivobook-15-512gb-ssd-16gb-ram-47-ghz/p/MLA21233402?pdp_filters=category:MLA1652#searchVariation=MLA21233402&position=2&search_layout=stack&type=product&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  2: {'product_name': 'Notebook Lenovo IdeaPad 3i Intel I5 1135g7 Ram 8gb Ssd 256gb Full hd Windows 11',
#   'price_tag_symbol': '$',
#   'product_price_number': '287.028',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '17',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-lenovo-ideapad-3i-intel-i5-1135g7-ram-8gb-ssd-256gb-full-hd-windows-11/p/MLA22892509?pdp_filters=category:MLA1652#searchVariation=MLA22892509&position=3&search_layout=stack&type=product&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  3: {'product_name': 'Notebook Iqual Nq1 Intel Celeron N4020 4gb 128gb W10 Full',
#   'price_tag_symbol': '$',
#   'product_price_number': '109.999',
#   'product_discount': '9% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '40',
#   'product_seller': 'Vendido por IQUAL',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-iqual-nq1-intel-celeron-n4020-4gb-128gb-w10-full/p/MLA19858863?pdp_filters=category:MLA1652#searchVariation=MLA19858863&position=4&search_layout=stack&type=product&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  4: {'product_name': 'Notebook HP 15-ef2529la plata natural 15.6", AMD Ryzen 5 5500U  8GB de RAM 512GB SSD, AMD Radeon RX Vega 7 1920x1080px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '459.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '11',
#   'product_seller': 'Vendido por HP Tienda Oficial',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-15-ef2529la-plata-natural-156-amd-ryzen-5-5500u-8gb-de-ram-512gb-ssd-amd-radeon-rx-vega-7-1920x1080px-windows-11-home/p/MLA23234618?pdp_filters=category:MLA1652#searchVariation=MLA23234618&position=5&search_layout=stack&type=product&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  5: {'product_name': 'Notebook Lenovo IdeaPad 15ITL6  arctic gray 15.6", Intel Core i7 1165G7  8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 96EUs 1920x1080px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '419.999',
#   'product_discount': '11% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '233',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-lenovo-ideapad-15itl6-arctic-gray-156-intel-core-i7-1165g7-8gb-de-ram-256gb-ssd-intel-iris-xe-graphics-g7-96eus-1920x1080px-windows-11-home/p/MLA23138330?pdp_filters=category:MLA1652#searchVariation=MLA23138330&position=6&search_layout=stack&type=product&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  6: {'product_name': 'Ultrabook Gadnic Cloudbook Glow Pro gray 14.1", Intel Celeron N3350  4GB de RAM 64GB SSD 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '154.999',
#   'product_discount': '18% OFF',
#   'product_cuotas': 'Mismo precio en 6 cuotas de $20.999',
#   'product_shipping': 'Envío gratis',
#   'product_reviews':
search_layout=stack&type=product&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  31: {'product_name': 'Notebook Acer Aspire 3 Celeron N4500 8gb 500gb 14  1',
#   'price_tag_symbol': '$',
#   'product_price_number': '174.949',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://articulo.mercadolibre.com.ar/MLA-1377503112-notebook-acer-aspire-3-celeron-n4500-8gb-500gb-14-1-_JM#position=44&search_layout=stack&type=item&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  32: {'product_name': 'Note Workstation Lenovo P14s R7 5850u 16gb 512gb W10p 14 Fhd',
#   'price_tag_symbol': '$',
#   'product_price_number': '1.113.629',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://articulo.mercadolibre.com.ar/MLA-1164297422-note-workstation-lenovo-p14s-r7-5850u-16gb-512gb-w10p-14-fhd-_JM#position=45&search_layout=stack&type=item&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  33: {'product_name': 'Notebook gamer Lenovo Ideapad 15IAH7  onyx gray 15.6", Intel Core i5 12500H  8GB de RAM 512GB SSD, NVIDIA GeForce RTX 3050 Ti 120 Hz 1920x1080px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '619.498',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-gamer-lenovo-ideapad-15iah7-onyx-gray-156-intel-core-i5-12500h-8gb-de-ram-512gb-ssd-nvidia-geforce-rtx-3050-ti-120-hz-1920x1080px-windows-11-home/p/MLA23286960?pdp_filters=category:MLA1652#searchVariation=MLA23286960&position=30&search_layout=stack&type=product&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  34: {'product_name': 'Notebook gamer Asus TUF Dash F15 negra 15.6", Intel Core i5 12450H  8GB de RAM 512GB SSD, NVIDIA GeForce RTX 3050 144 Hz 1920x1080px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '570.000',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-gamer-asus-tuf-dash-f15-negra-156-intel-core-i5-12450h-8gb-de-ram-512gb-ssd-nvidia-geforce-rtx-3050-144-hz-1920x1080px-windows-11-home/p/MLA23125533?pdp_filters=category:MLA1652#searchVariation=MLA23125533&position=31&search_layout=stack&type=product&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  35: {'product_name': 'Notebook Huawei Matebook D14 Intel I5 512gb Ssd 8gb Ram',
#   'price_tag_symbol': '$',
#   'product_price_number': '409.999',
#   'product_discount': None,
#   'product_cuotas': 'Mismo precio en 6 cuotas de $68.333',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': 'Vendido por Huawei',
#   'product_link': 'https://articulo.mercadolibre.com.ar/MLA-1392261018-notebook-huawei-matebook-d14-intel-i5-512gb-ssd-8gb-ram-_JM#position=46&search_layout=stack&type=item&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  36: {'product_name': 'Notebook Lenovo V-Series V15-G2-ITL  iron gray 15.6", Intel Core i5 1135G7  8GB de RAM 1TB HDD, Intel Iris Xe Graphics G7 80EUs 1920x1080px',
#   'price_tag_symbol': '$',
#   'product_price_number': '395.995',
#   'product_discount': '9% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '68',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-lenovo-v-series-v15-g2-itl-iron-gray-156-intel-core-i5-1135g7-8gb-de-ram-1tb-hdd-intel-iris-xe-graphics-g7-80eus-1920x1080px/p/MLA18721788?pdp_filters=category:MLA1652#searchVariation=MLA18721788&position=32&search_layout=stack&type=product&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  37: {'product_name': 'Notebook Asus ZenBook 14 UM425QA pine gray 14", AMD Ryzen 5 4500U  8GB de RAM 512GB SSD, AMD Radeon RX Vega 6 (Ryzen 4000/5000) 1920x1080px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '554.999',
#   'product_discount': '12% OFF',
#   'product_cuotas': 'Mismo precio en 3 cuotas de $162.799',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '44',
#   'product_seller': 'Vendido por ASUS',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-zenbook-14-um425qa-pine-gray-14-amd-ryzen-5-4500u-8gb-de-ram-512gb-ssd-amd-radeon-rx-vega-6-ryzen-40005000-1920x1080px-windows-11-home/p/MLA19488544?pdp_filters=category:MLA1652#searchVariation=MLA19488544&position=33&search_layout=stack&type=product&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  38: {'product_name': 'Notebook Xplode 14.1  Hd 6gb Ram 64gb Intel Windows 10 2mp',
#   'price_tag_symbol': '$',
#   'product_price_number': '99.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://articulo.mercadolibre.com.ar/MLA-1125369743-notebook-xplode-141-hd-6gb-ram-64gb-intel-windows-10-2mp-_JM#position=47&search_layout=stack&type=item&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#
search_layout=stack&type=product&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  47: {'product_name': 'Notebook Dell Inspiron 3520 Intel I7 1255u 16gb Ram 512gb',
#   'price_tag_symbol': '$',
#   'product_price_number': '579.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': 'Vendido por Start',
#   'product_link': 'https://articulo.mercadolibre.com.ar/MLA-1411517902-notebook-dell-inspiron-3520-intel-i7-1255u-16gb-ram-512gb-_JM#position=49&search_layout=stack&type=item&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  48: {'product_name': 'Apple MacBook Pro (16 pulgadas, Chip M1 Pro de Apple con CPU de 10 núcleos, GPU de 16 núcleos, 16 GB RAM, 512 GB SSD) - color plata',
#   'price_tag_symbol': '$',
#   'product_price_number': '1.481.253',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '2',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/apple-macbook-pro-16-pulgadas-chip-m1-pro-de-apple-con-cpu-de-10-nucleos-gpu-de-16-nucleos-16-gb-ram-512-gb-ssd-color-plata/p/MLA18624429?pdp_filters=category:MLA1652#searchVariation=MLA18624429&position=41&search_layout=stack&type=product&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  49: {'product_name': 'Notebook Cx 14 Amd A9-9400 Mejor Que I3 4gb Ssd 64gb 2',
#   'price_tag_symbol': '$',
#   'product_price_number': '130.929',
#   'product_discount': None,
#   'product_cuotas': 'Mismo precio en 6 cuotas de $21.821',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://articulo.mercadolibre.com.ar/MLA-1401869542-notebook-cx-14-amd-a9-9400-mejor-que-i3-4gb-ssd-64gb-2-_JM#position=50&search_layout=stack&type=item&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  50: {'product_name': "Notebook Lenovo Intel I5 1135g7 8gb 256gb 14'' Fhd Win 11",
#   'price_tag_symbol': '$',
#   'product_price_number': '349.999',
#   'product_discount': '17% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://articulo.mercadolibre.com.ar/MLA-1409567966-notebook-lenovo-intel-i5-1135g7-8gb-256gb-14-fhd-win-11-_JM#position=51&search_layout=stack&type=item&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  51: {'product_name': 'Notebook Asus Zenbook Duo Pro I7 32gb 1tb Win 11',
#   'price_tag_symbol': '$',
#   'product_price_number': '1.334.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': 'Vendido por ASUS',
#   'product_link': 'https://articulo.mercadolibre.com.ar/MLA-1218793382-notebook-asus-zenbook-duo-pro-i7-32gb-1tb-win-11-_JM#position=52&search_layout=stack&type=item&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  52: {'product_name': 'Notebook Lenovo 10th Gen Intel® Core I5 4gb Ram 256gb Ssd ',
#   'price_tag_symbol': '$',
#   'product_price_number': '210.000',
#   'product_discount': None,
#   'product_cuotas': 'Mismo precio en 6 cuotas de $35.000',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://articulo.mercadolibre.com.ar/MLA-1371518257-notebook-lenovo-10th-gen-intel-core-i5-4gb-ram-256gb-ssd-_JM#position=53&search_layout=stack&type=item&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'},
#  53: {'product_name': 'Notebook Gfast N-150-f Celeron N4020 4gb Ssd 128gb 15.6 1',
#   'price_tag_symbol': '$',
#   'product_price_number': '122.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://articulo.mercadolibre.com.ar/MLA-1389179944-notebook-gfast-n-150-f-celeron-n4020-4gb-ssd-128gb-156-1-_JM#position=54&search_layout=stack&type=item&tracking_id=7b8f3426-6ba6-4456-838f-d720c968b3c1'}}

# %%
# Creamos un dataframe a partir de un dict. Tenemos que aplicar transpose para que cambie filas por columnas 
df = pd.DataFrame(dict).transpose()

# %%
df
# Out:
#                                          product_name price_tag_symbol  \
# 0   Notebook Asus Vivobook 15 X1502 azul 15.6", In...                $
# 1   Notebook Asus I7 Vivobook 15 512gb Ssd 16gb Ra...                $
# 2   Notebook Lenovo IdeaPad 3i Intel I5 1135g7 Ram...                $
# 3   Notebook Iqual Nq1 Intel Celeron N4020 4gb 128...                $
# 4   Notebook HP 15-ef2529la plata natural 15.6", A...                $
# 5   Notebook Lenovo IdeaPad 15ITL6  arctic gray 15...                $
# 6   Ultrabook Gadnic Cloudbook Glow Pro gray 14.1"...                $
# 7   Notebook Hp 15-dy5001la Intel I5 1235u 8gb 512...                $
# 8   Notebook Hp Elitebook 840 G3 I5 6ta 256 Ssd 8g...                $
# 9   Notebook Bangho Max L5 Intel I5 8gb Ssd 240g 1...                $
# 10  Notebook Dell Inspiron 3525 plateada 15.5", AM...                $
# 11  Notebook gamer Asus TUF Gaming F15 FX506LHB bo...                $
# 12         Notebook Asus Amd R5-5600h 16gb 512g Win11                $
# 13  Notebook Gadnic Lumina Pro Intel Dual Core 4gb...                $
# 14  Apple MacBook Pro (16 pulgadas, Chip M1 Pro de...                $
# 15  Notebook HP 15-ef2514la plata 15.6", AMD Ryzen...                $
# 16  Notebook Cx 14 Amd A9-9400 Mejor Que I3 4gb Ss...                $
# 17  Notebook Lenovo IdeaPad 15ITL05  abyss blue 15...                $
# 18  Notebook Hp Elitebook 840 G5 I5 8gb Ram 256 Ss...                $
# 19  Notebook Asus Rog Strix G16 I7-13650hx 16gb 51...                $
# 20  Notebook Dell Inspiron 3525 plata 15.5", AMD R...                $
# 21  Apple MacBook Pro (13 pulgadas, 2020, Chip M1,...                $
# 22  Notebook Asus X515EA gris 15.6", Intel Core i5...                $
# 23  Apple MacBook Pro (13 pulgadas, 2020, Chip M1,...                $
# 24  Notebook Dell Inspiron 3520 Intel I7 1255u 16g...                $
# 25  Notebook Dell Inspiron 3515 Negra 15.6  , Amd ...                $
# 26  Notebook gamer Lenovo Legion 15ACH6H  shadow b...                $
# 27  Notebook Lenovo IdeaPad 15IIL05  almond táctil...                $
# 28  Notebook gamer MSI Thin GF63 negra 15.6", Inte...                $
# 29  Apple MacBook Pro (14 pulgadas, Chip M1 Pro de...                $
# 30  Notebook Lenovo IdeaPad 14ITL05  graphite gray...                $
# 31  Notebook Acer Aspire 3 Celeron N4500 8gb 500gb...                $
# 32  Note Workstation Lenovo P14s R7 5850u 16gb 512...                $
# 33  Notebook gamer Lenovo Ideapad 15IAH7  onyx gra...                $
# 34  Notebook gamer Asus TUF Dash F15 negra 15.6", ...                $
# 35  Notebook Huawei Matebook D14 Intel I5 512gb Ss...                $
# 36  Notebook Lenovo V-Series V15-G2-ITL  iron gray...                $
# 37  Notebook Asus ZenBook 14 UM425QA pine gray 14"...                $
# 38  Notebook Xplode 14.1  Hd 6gb Ram 64gb Intel Wi...                $
# 39  Notebook X View Windows 10 Novabook V2 Cloudbo...                $
# 40  Notebook Dell Inspiron 3520 plata 15.6", Intel...                $
# 41  LG Gram 15'' Ram 16gb Ssd 512gb Touchscreen La...                $
# 42  Notebook Lenovo Ideapad I7 1165g7 8gb 512gb Pa...                $
# 43  Notebook Lenovo IdeaPad 15ITL6  arctic grey 15...                $
# 44  Notebook Lenovo I5 1135g7 8gb Ram 512gb Ssd 14...                $
# 45  Notebook Asus Zenbook 14 Amd Ryzen 7-5825u 8 G...                $
# 46  Notebook Lenovo IdeaPad 3 81X700FGUS gris Inte...                $
# 47  Notebook Dell Inspiron 3520 Intel I7 1255u 16g...                $
# 48  Apple MacBook Pro (16 pulgadas, Chip M1 Pro de...                $
# 49  Notebook Cx 14 Amd A9-9400 Mejor Que I3 4gb Ss...                $
# 50  Notebook Lenovo Intel I5 1135g7 8gb 256gb 14''...                $
# 51   Notebook Asus Zenbook Duo Pro I7 32gb 1tb Win 11                $
# 52  Notebook Lenovo 10th Gen Intel® Core I5 4gb Ra...                $
# 53  Notebook Gfast N-150-f Celeron N4020 4gb Ssd 1...                $
#
#    product_price_number product_discount  \
# 0               449.999          18% OFF
# 1               644.999          15% OFF
# 2               287.028             None
# 3               109.999           9% OFF
# 4               459.999             None
# 5               419.999          11% OFF
# 6               154.999          18% OFF
# 7               529.999          20% OFF
# 8               292.000           7% OFF
# 9               434.999           6% OFF
# 10              400.000          12% OFF
# 11              624.999           7% OFF
# 12              599.999          12% OFF
# 13              215.399          35% OFF
# 14            1.705.275             None
# 15              584.999          23% OFF
# 16               96.989             None
# 17              283.999             None
# 18              330.000           7% OFF
# 19            1.510.199           9% OFF
# 20              584.999          25% OFF
# 21              999.999             None
# 22              449.990           9% OFF
# 23            1.119.998             None
# 24              799.999          27% OFF
# 25              499.999             None
# 26              789.999          17% OFF
# 27              274.999           9% OFF
# 28              500.000             None
# 29            1.399.999             None
# 30              384.374             None
# 31              174.949             None
# 32            1.113.629             None
# 33              619.498             None
# 34              570.000             None
# 35              409.999             None
# 36              395.995           9% OFF
# 37              554.999          12% OFF
# 38               99.999             None
# 39              149.999             None
# 40              739.021             None
# 41              600.000           9% OFF
# 42              332.999             None
# 43              649.999          15% OFF
# 44              299.999             None
# 45              672.900          20% OFF
# 46              199.999             None
# 47              579.999             None
# 48            1.481.253             None
# 49              130.929             None
# 50              349.999          17% OFF
# 51            1.334.999             None
# 52              210.000             None
# 53              122.999             None
#
#                           product_cuotas product_shipping product_reviews  \
# 0    Mismo precio en 6 cuotas de $61.499     Envío gratis             122
# 1    Mismo precio en 6 cuotas de $91.374     Envío gratis             130
# 2                                   None     Envío gratis              17
# 3                                   None     Envío gratis              40
# 4                                   None     Envío gratis              11
# 5                                   None     Envío gratis             233
# 6    Mismo precio en 6 cuotas de $20.999     Envío gratis             113
# 7    Mismo precio en 6 cuotas de $70.351     Envío gratis              57
# 8    Mismo precio en 6 cuotas de $45.077     Envío gratis            None
# 9    Mismo precio en 6 cuotas de $67.849     Envío gratis            None
# 10   Mismo precio en 6 cuotas de $58.333     Envío gratis             137
# 11                                  None     Envío gratis              31
# 12  Mismo precio en 3 cuotas de $175.999     Envío gratis            None
# 13   Mismo precio en 6 cuotas de $23.333     Envío gratis              88
# 14                                  None     Envío gratis               2
# 15   Mismo precio en 6 cuotas de $74.649     Envío gratis              24
# 16                                  None     Envío gratis            None
# 17                                  None     Envío gratis             109
# 18   Mismo precio en 6 cuotas de $50.943     Envío gratis            None
# 19                                  None     Envío gratis            None
# 20                                  None     Envío gratis             137
# 21                                  None     Envío gratis              71
# 22   Mismo precio en 6 cuotas de $67.686     Envío gratis             614
# 23                                  None     Envío gratis              71
# 24   Mismo precio en 6 cuotas de $96.666     Envío gratis            None
# 25  Mismo precio en 3 cuotas de $166.666     Envío gratis            None
# 26                                  None     Envío gratis            None
# 27                                  None     Envío gratis             114
# 28                                  None     Envío gratis              50
# 29                                  None     Envío gratis              23
# 30                                  None     Envío gratis            None
# 31                                  None     Envío gratis            None
# 32                                  None     Envío gratis            None
# 33                                  None     Envío gratis            None
# 34                                  None     Envío gratis            None
# 35   Mismo precio en 6 cuotas de $68.333     Envío gratis            None
# 36                                  None     Envío gratis              68
# 37  Mismo precio en 3 cuotas de $162.799     Envío gratis              44
# 38                                  None     Envío gratis            None
# 39                                  None     Envío gratis               4
# 40                                  None     Envío gratis            None
# 41                                  None     Envío gratis            None
# 42                                  None     Envío gratis              86
# 43  Mismo precio en 3 cuotas de $183.333     Envío gratis             233
# 44                                  None     Envío gratis              24
# 45                                  None     Envío gratis            None
# 46                                  None     Envío gratis            None
# 47                                  None     Envío gratis            None
# 48                                  None     Envío gratis               2
# 49   Mismo precio en 6 cuotas de $21.821     Envío gratis            None
# 50                                  None     Envío gratis            None
# 51                                  None     Envío gratis            None
# 52   Mismo precio en 6 cuotas de $35.000     Envío gratis            None
# 53                                  None     Envío gratis            None
#
#                    product_seller  \
# 0                Vendido por ASUS
# 1                Vendido por ASUS
# 2                            None
# 3               Vendido por IQUAL
# 4   Vendido por HP Tienda Oficial
# 5                            None
# 6              Vendido por Gadnic
# 7   Vendido por HP Tienda Oficial
# 8         Vendido por CPT Oficina
# 9              Vendido por Bidcom
# 10                           None
# 11               Vendido por ASUS
# 12               Vendido por ASUS
# 13             Vendido por Bidcom
# 14                           None
# 15  Vendido por HP Tienda Oficial
# 16                           None
# 17                           None
# 18        Vendido por CPT Oficina
# 19                           None
# 20               Vendido por Dell
# 21                           None
# 22                           None
# 23                           None
# 24                           None
# 25                           None
# 26                           None
# 27                           None
# 28                           None
# 29                           None
# 30                           None
# 31                           None
# 32                           None
# 33                           None
# 34                           None
# 35             Vendido por Huawei
# 36                           None
# 37               Vendido por ASUS
# 38                           None
# 39                           None
# 40                           None
# 41                           None
# 42                           None
# 43           Vendido por Megatone
# 44                           None
# 45                           None
# 46                           None
# 47              Vendido por Start
# 48                           None
# 49                           None
# 50                           None
# 51               Vendido por ASUS
# 52                           None
# 53                           None
#
#                                          product_link
# 0   https://www.mercadolibre.com.ar/notebook-asus-...
# 1   https://www.mercadolibre.com.ar/notebook-asus-...
# 2   https://www.mercadolibre.com.ar/notebook-lenov...
# 3   https://www.mercadolibre.com.ar/notebook-iqual...
# 4   https://www.mercadolibre.com.ar/notebook-hp-15...
# 5   https://www.mercadolibre.com.ar/notebook-lenov...
# 6   https://www.mercadolibre.com.ar/ultrabook-gadn...
# 7   https://www.mercadolibre.com.ar/notebook-hp-15...
# 8   https://click1.mercadolibre.com.ar/mclics/clic...
# La única diferencia respecto al anterior, es que ahora creamos un bucle por encima para que cargue una nuevapágina
# una vez que obtuvo la información de todos los productos de un página.
for page in pages:
    
    url = 'https://listado.mercadolibre.com.ar/computacion/laptops-accesorios/notebooks/notebook_Desde_' + str(page) + '_NoIndex_True' 
    soup = request_url(url)
    
    item_list = soup.find_all('div', class_="ui-search-result__content-wrapper shops__result-content-wrapper")
    
    for item in item_list:
        product_name = item.find('h2')
        product_price_symbol = item.find('span', {'class' : 'price-tag-symbol'})
        product_price_number = item.find('span', {'class' : 'price-tag-fraction'})
        product_discount = item.find('span', {'class' : 'ui-search-price__discount shops__price-discount'})
        product_cuotas = item.find('span', {'class' : 'ui-search-item__group__element shops__items-group-details ui-search-installments ui-search-color--LIGHT_GREEN'})
        product_shipping = item.find('p', {'class' : 'ui-search-item__shipping ui-search-item__shipping--free shops__item-shipping-free'})
        product_reviews = item.find('span', {'class' : 'ui-search-reviews__amount'})
        product_seller = item.find('p', {'class' : 'ui-search-official-store-label ui-search-item__group__element shops__items-group-details ui-search-color--GRAY'})
        product_label = item.find('label', {'class': 'ui-search-styled-label ui-search-item__highlight-label__text'})
        product_link = item.find('a').get('href')
        product_old_price = item.find('span', {'class':'price-tag-text-sr-only'})
        product_name = product_name.text

    #     If find_all() can’t find anything, it returns an empty list. If find() can’t find anything, it returns None

    #   .text is just a property that calls get_text. Therefore, calling get_text without arguments is 
    #   the same thing as .text. However, get_text can also support various keyword arguments to change how 
    #   it behaves (separator, strip, types). If you need more control over the result, 
    #   then you need the functional form.

        if product_price_symbol is not None:
            product_price_symbol = product_price_symbol.get_text()
        if product_price_number is not None:
            product_price_number = product_price_number.get_text()
        if product_discount is not None:
            product_discount = product_discount.get_text()
        if product_cuotas is not None:
            product_cuotas = product_cuotas.get_text()
        if product_shipping is not None:
            product_shipping = product_shipping.get_text()
        if product_reviews is not None:
            product_reviews = product_reviews.get_text()
        if product_seller is not None:
            product_seller = product_seller.get_text()
        if product_label is not None:
            product_label = product_label.get_text()
        if product_old_price is not None:
            product_old_price = product_old_price.get_text()
            

        dict.update({i:{
            'product_name': product_name,
            'price_tag_symbol': product_price_symbol,
            'product_price_number': product_price_number,
            'product_label': product_label,
            'product_old_price':product_old_price,
            'product_discount': product_discount,
            'product_cuotas': product_cuotas,
            'product_shipping': product_shipping,
            'product_reviews': product_reviews,
            'product_seller': product_seller,
            'product_link': product_link
        }})

        i= i + 1

# %%
df = pd.DataFrame(dict).transpose()

# %%
df
# Out:
#                                           product_name price_tag_symbol  \
# 0    Ultrabook Gadnic Cloudbook Glow Pro gray 14.1"...                $
# 1    Notebook Banghó Max L5 i7 gris oscura 15.6", I...                $
# 2    Notebook Asus Vivobook 15 X1502 azul 15.6", In...                $
# 3    Notebook Asus I7 Vivobook 15 512gb Ssd 16gb Ra...                $
# 4    Notebook HP 15-ef2529la plata natural 15.6", A...                $
# ..                                                 ...              ...
# 375  Notebook Nsx Kairos Ultraslim Intel I5 16gb Ss...                $
# 376  Notebook Banghó Max L5 i3 gris oscura 15.6", I...                $
# 377  Notebook Lenovo Ideapad 3 Intel I7 256gb Ssd 8...                $
# 378  Notebook Bangho Max L5 Core I7 Ram 8gb Ssd 480...                $
# 379  Notebook Iqual Nq1 Intel Celeron N4020 4gb 128...                $
#
#     product_price_number   product_label    product_old_price  \
# 0                154.999            None  Antes: 154999 pesos
# 1                596.899            None  Antes: 596899 pesos
# 2                449.999  OFERTA DEL DÍA  Antes: 449999 pesos
# 3                644.999  OFERTA DEL DÍA  Antes: 644999 pesos
# 4                459.999     MÁS VENDIDO         459999 pesos
# ..                   ...             ...                  ...
# 375              401.248            None         401248 pesos
# 376              284.999            None         284999 pesos
# 377              449.999            None         449999 pesos
# 378              202.999            None         202999 pesos
# 379              119.999            None  Antes: 119999 pesos
#
#     product_discount                       product_cuotas product_shipping  \
# 0            18% OFF  Mismo precio en 6 cuotas de $20.999             None
# 1            34% OFF                                 None             None
# 2            18% OFF  Mismo precio en 6 cuotas de $61.499     Envío gratis
# 3            15% OFF  Mismo precio en 6 cuotas de $91.374     Envío gratis
# 4               None                                 None             None
# ..               ...                                  ...              ...
# 375             None                                 None     Envío gratis
# 376             None                                 None     Envío gratis
# 377             None                                 None     Envío gratis
# 378             None                                 None     Envío gratis
# 379          13% OFF                                 None     Envío gratis
#
#     product_reviews                 product_seller  \
# 0               113             Vendido por Gadnic
# 1                43             Vendido por Bidcom
# 2               122               Vendido por ASUS
# 3               130               Vendido por ASUS
# 4                11  Vendido por HP Tienda Oficial
# ..              ...                            ...
# 375            None                           None
# 376              54                           None
# 377            None              Vendido por Start
# 378            None                           None
# 379            None                           None
#
#                                           product_link
# 0    https://click1.mercadolibre.com.ar/mclics/clic...
# 1    https://click1.mercadolibre.com.ar/mclics/clic...
# 2    https://www.mercadolibre.com.ar/notebook-asus-...
# 3    https://www.mercadolibre.com.ar/notebook-asus-...
# 4    https://www.mercadolibre.com.ar/notebook-hp-15...
# ..                                                 ...
# 375  https://articulo.mercadolibre.com.ar/MLA-11668...
# 376  https://www.mercadolibre.com.ar/notebook-bangh...
# 377  https://articulo.mercadolibre.com.ar/MLA-13686...
# 378  https://articulo.mercadolibre.com.ar/MLA-13646...
# 379  https://articulo.mercadolibre.com.ar/MLA-11320...
#
# [380 rows x 11 columns]

# %%
primera = [0, 1, 2, 3, 4]
segunda = ['a', 'b', 'c', 'd']

# %%
for i in primera:
    print(i)
    print("------------")
    for b in segunda:
        print("                 " +str(b))
        if b = 'b':
            exit
        print('                  ===============')
# Out:
# 0
# ------------
#                  a
#                   ===============
#                  b
#                   ===============
#                  c
#                   ===============
#                  d
#                   ===============
# 1
# ------------
#                  a
#                   ===============
#                  b
#                   ===============
#                  c
#                   ===============
#                  d
#                   ===============
# 2
# ------------
#                  a
#                   ===============
#                  b
#                   ===============
#                  c
#                   ===============
#                  d
#                   ===============
# 3
# ------------
#                  a
#                   ===============
#                  b
#                   ===============
#                  c
#                   ===============
#                  d
#                   ===============
# 4
# ------------
#                  a
#                   ===============
#                  b
#                   ===============
#                  c
#                   ===============
#                  d
#                   ===============
